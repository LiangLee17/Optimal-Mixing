# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
l1path = './l1norm_histogram.txt'
l2path = './l2norm_histogram.txt'
mixpath = './mixnorm_histogram.txt'

# %%
l1 = np.genfromtxt(l1path, dtype=[int, float])
l1pd = pd.DataFrame(l1)
l1pd['f0'] = l1pd['f0']/100
sns.lineplot(data=l1pd, x = 'f0', y = 'f1')
# Out:
# <AxesSubplot:xlabel='f0', ylabel='f1'>
